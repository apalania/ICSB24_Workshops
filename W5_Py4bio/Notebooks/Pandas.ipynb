# %% [markdown]
# # **PANDAS**
#
# - Python library for working with data sets.
#
# - A library that provides high-performance, easy-to-use data structures and data
# analysis tools Python.

# %% [markdown]
# #### Import the pandas package

# %%
import pandas as pd

# %% [markdown]
# Data Structures

# %% [markdown]
# Create a series

# %%
# series
s = pd.Series(np.random.rand(1000), index=range(1000))

# %% [markdown]
# Create a time index

# %%
# time index
index = pd.date_range("13/06/2016", periods=1000)

# %% [markdown]
# Create a  DataFrame
#
# - syntax: pd.DataFrame({column1 : value1, column2 : value2, column3 : value3})

# %%
df = pd.DataFrame({'name':['Bob','Jen','Tim','Sky','seth','lee'],
                   'age':[20,30,40,25,32,40],
                   'occupation':['Student','Teacher','Lawyer','systems analysit','HR','Doctor']})

df
# Out:
#    name  age        occupation
# 0   Bob   20           Student
# 1   Jen   30           Teacher
# 2   Tim   40            Lawyer
# 3   Sky   25  systems analysit
# 4  seth   32                HR
# 5   lee   40            Doctor

# %% [markdown]
# get the column names

# %%
df.columns
# Out:
# Index(['name', 'age', 'occputation'], dtype='object')

# %% [markdown]
# get the index values

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# get data types of all columns

# %%
df.dtypes
# Out:
# name           object
# age             int64
# occputation    object
# dtype: object

# %% [markdown]
# get first 5 rows

# %%
df.head(5)
# Out:
#    name  age       occputation
# 0   Bob   20           Student
# 1   Jen   30           Teacher
# 2   Tim   40            Lawyer
# 3   Sky   25  systems analysit
# 4  seth   32                HR

# %% [markdown]
# get basic statisitics for all columns

# %%
df.describe()

# %% [markdown]
# #### Select a column by name in 2 different ways

# %%
print(df['name'])
print(df.name)
# Out:
# 0     Bob
# 1     Jen
# 2     Tim
# 3     Sky
# 4    seth
# 5     lee
# Name: name, dtype: object
# 0     Bob
# 1     Jen
# 2     Tim
# 3     Sky
# 4    seth
# 5     lee
# Name: name, dtype: object

# %% [markdown]
# #### Select multiple columns

# %%
df[['name','occupation']]
# Out:
#    name        occupation
# 0   Bob           Student
# 1   Jen           Teacher
# 2   Tim            Lawyer
# 3   Sky  systems analysit
# 4  seth                HR
# 5   lee            Doctor

# %% [markdown]
# #### Select a row by index

# %%
df.iloc[0]
# Out:
# name              Bob
# age                20
# occupation    Student
# Name: 0, dtype: object

# %% [markdown]
# ### Sort Function

# %%
df.sort_values('occupation',inplace=True, ascending=True)                              # sort the entire dataframe alphabetically
df
# Out:
#    name  age        occupation
# 5   lee   40            Doctor
# 4  seth   32                HR
# 2   Tim   40            Lawyer
# 0   Bob   20           Student
# 1   Jen   30           Teacher
# 3   Sky   25  systems analysit

# %% [markdown]
# #### Difference between loc and iloc
#
# - `.loc` selection is based on the value of the index. For example if the index was categorical we could index via some category.
# - `.iloc` selection is **always** based on integer positions. When using iloc we are treating the dataframe as 2d-array with no special structure compared to the case of `.loc`

# %%
df.loc[0]                                                                       #the data at index 0 is given as output
# Out:
# name              Bob
# age                20
# occupation    Student
# Name: 0, dtype: object

# %%
df.iloc[0]                                                                      # this pirnts the data that is present at the 1st position in the dataframe
# Out:
# name             lee
# age               40
# occupation    Doctor
# Name: 5, dtype: object
